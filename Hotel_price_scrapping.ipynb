# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import urllib.parse
import time
import requests
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
from selenium.webdriver.chrome.options import Options
#driver = webdriver.Chrome(executable_path='/Users/User/Upwork Project/PlanetX/chromedriver')
# driver.maximize_window()
chrome_options = Options()
# chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument(
    'user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36')
# options.add_argument("--window-size=1920,1080")
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("lang=en-GB")
chrome_options.add_argument('--ignore-certificate-errors')
# self.options.add_argument('--lang=en')
chrome_options.add_argument('--allow-running-insecure-content')
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--proxy-server='direct://'")
chrome_options.add_argument("--proxy-bypass-list=*")
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--no-sandbox')
# self.options.add_argument("--log-level=OFF")
chrome_options.add_argument("--log-level=3")
# driver = webdriver.Chrome(ChromeDriverManager().install())
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
driver.maximize_window()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12220\540929498.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# C:\Users\User\AppData\Local\Temp\ipykernel_12220\540929498.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

# %%
driver.get("https://www.hotels.com/")

# %%
inputt=driver.find_element(By.CSS_SELECTOR,"#destination_form_field-menu > div > div > div.uitk-field.has-floatedLabel-label.has-icon > button")

# %%
inputt.send_keys("DoubleTree by Hilton Hotel & Suites Houston by the Galleria")

# %%
driver.find_element(By.CSS_SELECTOR,"#search_button").click()

# %%
item=driver.find_element(By.CSS_SELECTOR,"#destination_form_field-menu > section > div > div.uitk-sheet-content.uitk-layout-flex-item.uitk-typeahead-menu-content > div > ul > li.uitk-action-list-item.uitk-typeahead-result-item.has-subtext.uitk-action-list-item-relaxed > div > button").click()

# %%
current_url=driver.current_url

# %%
date=[
        "2023-06-01:2023-06-02","2023-06-01:2023-06-03","2023-06-01:2023-06-04",
        "2023-06-02:2023-06-03","2023-06-02:2023-06-04","2023-06-02:2023-06-05",
        "2023-06-08:2023-06-09","2023-06-08:2023-06-10","2023-06-08:2023-06-11"]

# %%
# Your variable date
start_date = date[0].split(":")[0]
end_date = date[0].split(":")[1]

# Original URL
url=current_url
parsed_url = urllib.parse.urlparse(url)

# Get the query parameters
query_params = urllib.parse.parse_qs(parsed_url.query)

# Update the start date and end date
query_params['startDate'] = [start_date]
query_params['endDate'] = [end_date]

# Reconstruct the URL
updated_url = urllib.parse.urlunparse(
    (parsed_url.scheme, parsed_url.netloc, parsed_url.path,
     parsed_url.params, urllib.parse.urlencode(query_params, doseq=True), parsed_url.fragment)
)

print(updated_url)
# Out:
# https://www.hotels.com/Hotel-Search?adults=2&destination=Houston%2C+Texas%2C+United+States+of+America&endDate=2023-05-30&latLong=29.84287%2C-95.49552&regionId=1503&selected=2266&sort=RECOMMENDED&startDate=2023-05-29&useRewards=false

# %%
hotel_link=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > a").get_attribute("href")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 hotel_link=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > a").get_attribute("href")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
driver.get(hotel_link)

# %%
price=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-layout-grid.uitk-layout-grid-has-auto-columns.uitk-layout-grid-has-columns.uitk-layout-grid-has-columns-by-medium.uitk-layout-grid-has-columns-by-large.uitk-layout-grid-has-space.uitk-layout-grid-display-grid.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column.uitk-layout-grid-item.uitk-layout-grid-item-align-self-end.uitk-layout-grid-item-has-column-start.uitk-layout-grid-item-justify-self-end > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column > div:nth-child(2)").text

# %%
price=int(price.split("$")[1].split(" ")[0])

# %%
price
# Out:
# 366

# %%
scraped_name=driver.find_element(By.TAG_NAME,"h1").text

# %%
# Out:
# 'DoubleTree by Hilton Houston Brookhollow'

# %%
import pandas as pd

# %%
file=pd.read_excel("inp.xlsx")

# %%
Dic= {}
gc= pd.DataFrame(data=Dic,index=[0],columns=["Main_name","Scrapped_name","Price","start_date","end_date"])

# %%
for i in range(0,34):
    given_name=file.Hotel[i*12]
    driver.get("https://www.hotels.com/")
    time.sleep(4)
    inputt=driver.find_element(By.CSS_SELECTOR,"#destination_form_field-menu > div > div > div.uitk-field.has-floatedLabel-label.has-icon > button")
    inputt.send_keys(f"x {given_name}")
    time.sleep(15)
    try:
        item=driver.find_element(By.CSS_SELECTOR,"#destination_form_field-menu > section > div > div.uitk-sheet-content.uitk-layout-flex-item.uitk-typeahead-menu-content > div > ul > li.uitk-action-list-item.uitk-typeahead-result-item.has-subtext.uitk-action-list-item-relaxed > div > button").click()
        driver.find_element(By.CSS_SELECTOR,"#search_button").click()
        time.sleep(3)
    except:
        Dic={"Main_name":given_name,"Scrapped_name":"Cross","Price":"cross","start_date":"NA","end_date":"NA"}
        gc= gc.append(Dic, ignore_index=True)
        continue
    current_url=driver.current_url
    
    
    for a in range(12):
        price="Sold out"
        # Your variable date
        start_date = date[a].split(":")[0]
        end_date = date[a].split(":")[1]

        # Original URL
        url=current_url
        parsed_url = urllib.parse.urlparse(url)

        # Get the query parameters
        query_params = urllib.parse.parse_qs(parsed_url.query)

        # Update the start date and end date
        query_params['startDate'] = [start_date]
        query_params['endDate'] = [end_date]

        # Reconstruct the URL
        updated_url = urllib.parse.urlunparse(
            (parsed_url.scheme, parsed_url.netloc, parsed_url.path,
             parsed_url.params, urllib.parse.urlencode(query_params, doseq=True), parsed_url.fragment)
        )
        driver.get(updated_url)
        time.sleep(2)
        try:
            scraped_name=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-spacing.uitk-spacing-padding-blockend-three.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-justify-content-space-between.uitk-layout-flex-gap-two > div > h4").text
        except:
            continue
        try:
            price=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-layout-grid.uitk-layout-grid-has-auto-columns.uitk-layout-grid-has-columns.uitk-layout-grid-has-columns-by-medium.uitk-layout-grid-has-columns-by-large.uitk-layout-grid-has-space.uitk-layout-grid-display-grid.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column.uitk-layout-grid-item.uitk-layout-grid-item-align-self-end.uitk-layout-grid-item-has-column-start.uitk-layout-grid-item-justify-self-end > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column > div:nth-child(2)").text
            
        except:
            Dic={"Main_name":given_name,"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
            gc= gc.append(Dic, ignore_index=True)
            continue
        try:
            price=int(price.split("$")[1].split(" ")[0])
        except:
            Dic={"Main_name":given_name,"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
            gc= gc.append(Dic, ignore_index=True)
            continue
            
        
        Dic={"Main_name":given_name,"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
        gc= gc.append(Dic, ignore_index=True)
        print(gc)
        if len(gc)%10==0:
            gc.to_excel("output_hotel_4.xlsx")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13548\3937089947.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
#             Main_name       Scrapped_name Price  start_date    end_date
# 0                 NaN                 NaN   NaN         NaN         NaN
# 1  Omni Severin Hotel  Omni Severin Hotel   152  2023-05-31  2023-06-01
# C:\Users\User\AppData\Local\Temp\ipykernel_13548\3937089947.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
#             Main_name       Scrapped_name Price  start_date    end_date
# 0                 NaN                 NaN   NaN         NaN         NaN
# 1  Omni Severin Hotel  Omni Severin Hotel   152  2023-05-31  2023-06-01
# ...

# %%
gc.to_excel("output_hotel_6.xlsx")

# %%
gc
# Out:
#                                       Main_name  \
# 0                                           NaN
# 1  Sandcastle Oceanfront Resort At The Pavilion
# 2  Sandcastle Oceanfront Resort At The Pavilion
# 3  Sandcastle Oceanfront Resort At The Pavilion
#
#                               Scrapped_name       Price  start_date  \
# 0                                       NaN         NaN         NaN
# 1  Sandcastle Oceanfront Resort South Beach  $124 total  2023-05-31
# 2  Sandcastle Oceanfront Resort South Beach  $223 total  2023-05-31
# 3  Sandcastle Oceanfront Resort South Beach  $428 total  2023-05-31
#
#      end_date
# 0         NaN
# 1  2023-06-01
# 2  2023-06-02
# 3  2023-06-03

# %%
scraped_name=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-spacing.uitk-spacing-padding-blockend-three.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-justify-content-space-between.uitk-layout-flex-gap-two > div > h4").text

# %%
file
# Out:
#                                                 Hotel  \
# 0                                         The Chifley
# 1   The Darcy Washington DC, Curio Collection by H...
# 2                                   The Delaney Hotel
# 3                          The Georgian Terrace Hotel
# 4                           The Godfrey Hotel Chicago
# 5                                      The Link Hotel
# 6                             The LINQ Hotel & Casino
# 7                                  The Luxor & Casino
# 8                         The Mirage Hotel and Casino
# 9                                        The Normandy
# 10                       The Portofino Hotel & Marina
# 11                                  The Sandbar Hotel
# 12       The St. Clair Hotel - a Red Collection Hotel
# 13  The Viv Hotel, Anaheim, A Tribute Portfolio Hotel
# 14                        The Westin Buckhead Atlanta
# 15                     The Westin Dallas Park Central
# ...

# %%
file.Hotel[a]
# Out:
# 'The Link Hotel'

# %%
Dic= {}
gc= pd.DataFrame(data=Dic,index=[0],columns=["Main_name","Scrapped_name","Price","start_date","end_date"])

# %%
for b in range (len(file)):
    current_url=file.Link_H[b]
    for a in range(9):
        price="Sold out"
        # Your variable date
        start_date = date[a].split(":")[0]
        end_date = date[a].split(":")[1]

        # Original URL
        url=current_url
        parsed_url = urllib.parse.urlparse(url)

        # Get the query parameters
        query_params = urllib.parse.parse_qs(parsed_url.query)

        # Update the start date and end date
        query_params['startDate'] = [start_date]
        query_params['endDate'] = [end_date]

        # Reconstruct the URL
        updated_url = urllib.parse.urlunparse(
            (parsed_url.scheme, parsed_url.netloc, parsed_url.path,
             parsed_url.params, urllib.parse.urlencode(query_params, doseq=True), parsed_url.fragment)
        )
        driver.get(updated_url)
        time.sleep(2)
        try:
            scraped_name=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(3) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-spacing.uitk-spacing-padding-blockend-three.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-justify-content-space-between.uitk-layout-flex-gap-two > div > h4").text
        except:
            continue
        try:
            price=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(3) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-layout-grid.uitk-layout-grid-has-auto-columns.uitk-layout-grid-has-columns.uitk-layout-grid-has-columns-by-medium.uitk-layout-grid-has-columns-by-large.uitk-layout-grid-has-space.uitk-layout-grid-display-grid.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column.uitk-layout-grid-item.uitk-layout-grid-item-align-self-end.uitk-layout-grid-item-has-column-start.uitk-layout-grid-item-justify-self-end > div > div:nth-child(2) > div").text

        except:
            Dic={"Main_name":file.Hotel[b],"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
            gc= gc.append(Dic, ignore_index=True)
            continue
        # try:
        #     price=int(price.split(" ")[1])
        # except:
        #     Dic={"Main_name":file.Hotel[a],"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
        #     gc= gc.append(Dic, ignore_index=True)
        #     continue


        Dic={"Main_name":file.Hotel[b],"Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
        gc= gc.append(Dic, ignore_index=True)
        print(gc)
        if len(gc)%10==0:
            gc.to_excel("output_hotel_7.xlsx")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12220\2723498932.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
#      Main_name                                      Scrapped_name       Price  \
# 0          NaN                                                NaN         NaN
# 1  The Chifley  The Chifley Houston, Tapestry Collection by Hi...  $247 total
#
#    start_date    end_date
# 0         NaN         NaN
# 1  2023-06-01  2023-06-02
# C:\Users\User\AppData\Local\Temp\ipykernel_12220\2723498932.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
#      Main_name                                      Scrapped_name       Price  \
# 0          NaN                                                NaN         NaN
# ...

# %%
gc
# Out:
#   Main_name Scrapped_name Price start_date end_date
# 0       NaN           NaN   NaN        NaN      NaN

# %%
x="https://www.hotels.com/Hotel-Search?MDPDTL=HTL.1234327.20230609.20230610.DDF.9.CID.18634265726.AUDID.&adults=2&children=&destination=Toronto%2C%20Ontario%2C%20Canada&endDate=2023-06-10&gclid=Cj0KCQjw4NujBhC5ARIsAF4Iv6flaEwdRUABTlh9c0pvVpf9Z2HHsXscZH0PHKMfa1krzZ56LcVS1RAaAsMsEALw_wcB&mctc=10&mdpcid=HCOM-BD.META.HPA.HOTEL-CORESEARCH-desktop.HOTEL&mpf=58889.04&mpg=BDT&mpj=9723.03&mpl=USD&rateplanid=206340125&regionId=4089&rffrid=sem.hcom.BD.156.003.localuniversal.02.desktop-1.kwrd%3DGGMETA.231487BDen-20230609-N-ABW%3D9-camp%3D18634265726-aud%3D-N&selected=1234327&semdtl=&sort=RECOMMENDED&startDate=2023-06-09&theme=&useRewards=false&userIntent="

# %%
gc.to_excel("day5.xlsx")

# %%
current_url=x
for a in range(12):
    price="Sold out"
    # Your variable date
    start_date = date[a].split(":")[0]
    end_date = date[a].split(":")[1]

    # Original URL
    url=current_url
    parsed_url = urllib.parse.urlparse(url)

    # Get the query parameters
    query_params = urllib.parse.parse_qs(parsed_url.query)

    # Update the start date and end date
    query_params['startDate'] = [start_date]
    query_params['endDate'] = [end_date]

    # Reconstruct the URL
    updated_url = urllib.parse.urlunparse(
        (parsed_url.scheme, parsed_url.netloc, parsed_url.path,
         parsed_url.params, urllib.parse.urlencode(query_params, doseq=True), parsed_url.fragment)
    )
    driver.get(updated_url)
    time.sleep(2)
    try:
        scraped_name=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-spacing.uitk-spacing-padding-blockend-three.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-justify-content-space-between.uitk-layout-flex-gap-two > div > h4").text
    except:
        continue
    try:
        price=driver.find_element(By.CSS_SELECTOR,"#app-layer-base > div:nth-child(1) > main > div > div > div > div > div.uitk-layout-flex-item.uitk-layout-flex-item-flex-grow-1 > section:nth-child(2) > div > div.uitk-spacing.search-results-listing.uitk-spacing-padding-small-block-three.uitk-spacing-padding-medium-blockstart-one.uitk-spacing-padding-large-blockstart-three > div > div:nth-child(2) > div:nth-child(3) > div:nth-child(2) > div:nth-child(2) > div > div > div.uitk-card-content-section.uitk-card-content-section-padded.uitk-layout-grid-item.uitk-layout-grid-item-has-column-start-by-medium > div > div.uitk-layout-grid.uitk-layout-grid-has-auto-columns.uitk-layout-grid-has-columns.uitk-layout-grid-has-columns-by-medium.uitk-layout-grid-has-columns-by-large.uitk-layout-grid-has-space.uitk-layout-grid-display-grid.uitk-layout-flex-item > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column.uitk-layout-grid-item.uitk-layout-grid-item-align-self-end.uitk-layout-grid-item-has-column-start.uitk-layout-grid-item-justify-self-end > div.uitk-layout-flex.uitk-layout-flex-flex-direction-column > div:nth-child(2)").text

    except:
        Dic={"Main_name":"given_name","Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
        gc= gc.append(Dic, ignore_index=True)
        continue
    try:
        price=int(price.split(" ")[1])
    except:
        Dic={"Main_name":"given_name","Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
        gc= gc.append(Dic, ignore_index=True)
        continue


    Dic={"Main_name":"given_name","Scrapped_name":scraped_name,"Price":price,"start_date":start_date,"end_date":end_date}
    gc= gc.append(Dic, ignore_index=True)
    print(gc)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13548\1415851477.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_13548\1415851477.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_13548\1415851477.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc= gc.append(Dic, ignore_index=True)
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[23], line 24
#      19 # Reconstruct the URL
#      20 updated_url = urllib.parse.urlunparse(
# ...

# %%
gc
# Out:
#       Main_name                                      Scrapped_name  \
# 0           NaN                                                NaN
# 1    given_name  Pelican Grand Beach Resort - A Noble House Resort
# 2    given_name  Pelican Grand Beach Resort - A Noble House Resort
# 3    given_name  Pelican Grand Beach Resort - A Noble House Resort
# 4    given_name  Pelican Grand Beach Resort - A Noble House Resort
# ..          ...                                                ...
# 119  given_name    The Chicago Hotel Collection - Magnificent Mile
# 120  given_name    The Chicago Hotel Collection - Magnificent Mile
# 121  given_name                    One King West Hotel & Residence
# 122  given_name                    One King West Hotel & Residence
# 123  given_name                    One King West Hotel & Residence
#
#             Price  start_date    end_date
# 0             NaN         NaN         NaN
# 1      $363 total  2023-05-31  2023-06-01
# ...
